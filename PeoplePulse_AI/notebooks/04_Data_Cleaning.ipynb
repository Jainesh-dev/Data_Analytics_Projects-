# %% [markdown]
# # Phase 4: Data Cleaning
#
# ## Objective
#
# The objective of this notebook is to clean the employee dataset by handling data quality issues identified during the profiling phase, ensuring that the dataset is suitable for exploratory analysis and business intelligence.

# %% [markdown]
# ## Business Context
#
# The data profiling phase confirmed that the dataset contains no missing values and no duplicate records. However, three constant features provide no analytical value and will be removed to improve the quality of subsequent analysis.

# %%
import pandas as pd
df=pd.read_csv("../data/raw/WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Observation
#
# No missing values were detected in any feature. Therefore, no missing value treatment was required.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["EmployeeCount","Over18","StandardHours"],inplace=True,errors="ignore")

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 32)

# %%
df.to_csv("../data/processed/employee_attrition_cleaned.csv", index=False)

# %% [markdown]
# | Cleaning Step     | Status | Remarks            |
# | ----------------- | ------ | ------------------ |
# | Missing Values    | ✅      | No action required |
# | Duplicate Records | ✅      | No action required |
# | Constant Columns  | ✅      | Removed            |
# | Dataset Saved     | ✅      | Ready for EDA      |

# %% [markdown]
# ## Analyst Notes
#
# ### Key Findings
#
# - No missing values were detected.
# - No duplicate records were found.
# - Three constant columns were removed.
# - The cleaned dataset is ready for exploratory data analysis.
#
# ### Risks
#
# - No major data quality risks remain after cleaning.
#
# ### Next Phase
#
# Perform Exploratory Data Analysis (EDA) to identify the factors influencing employee attrition.

# %% [markdown]
# ## Business Impact
#
# Removing non-informative features reduces unnecessary complexity and ensures that subsequent analysis focuses only on variables that contribute meaningful business insights.

# %% [markdown]
# ## Conclusion
#
# The dataset has been successfully cleaned by removing non-informative features while preserving all relevant employee information. The cleaned dataset is now ready for exploratory analysis.
